# %%
from imutils.paths import list_images
import ipyplot
import cv2
import random

# %%
# Пример использования
input_directory = './test_images_0'
output_directory = './test_images_2'
watermark_text = 'WATERMARK'

imagePaths = list(list_images(input_directory))

from tqdm import tqdm

for imagePath in tqdm(imagePaths, total=len(imagePaths), position=0):
    image = cv2.imread(imagePath)
    image = cv2.resize(image, (256, 256))
#     for i in range(3):
#         cv2.putText(image, watermark_text,
#             (10, random.randint(10, 200)),
#             cv2.FONT_HERSHEY_SIMPLEX,
#             1,
#             (255, 255, 255),
#             1,
#             2)
    
    img_name = imagePath.split(os.path.sep)[-1]
    new_image_path = output_directory + '/' + img_name

    cv2.imwrite(new_image_path, image)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 310.99it/s]

# %%
ipyplot.plot_images(
    [image], 
    ['predictions']
)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-bgDn3zf8V4FAs83PpfqAAp {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-bgDn3zf8V4FAs83PpfqAAp {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-bgDn3zf8V4FAs83PpfqAAp {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-bgDn3zf8V4FAs83PpfqAAp:checked ~ #ipyplot-html-viewer-textarea-bgDn3zf8V4FAs83PpfqAAp {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-bgDn3zf8V4FAs83PpfqAAp:checked + #ipyplot-html-viewer-label-bgDn3zf8V4FAs83PpfqAAp:after {
# ...
